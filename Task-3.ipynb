# %% [markdown]
# ### Name: DEBARTHA PAUL

# %% [markdown]
# # VIP Data Science Task-3: Image to pencil sketch using Python

# %% [markdown]
# ### Description:

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# ### Importing the libraries

# %% [markdown]
# First we import the necessary libraries required for our work

# %%
import cv2  #reading the images
from google.colab.patches import cv2_imshow #viewing the images in colab

# %% [markdown]
# ### Function for pencil sketch

# %% [markdown]
# Then, we create a user-defined function with the parameter as the image name and address to read the images, and convert it into a pancil-sketch

# %%
def sketch(path):   #creating a user-defined function which'll convert an image to pencil sketch
    img=cv2.imread(path)    #reading the image
    print('Loaded Image')
    cv2_imshow(img)
    newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #converting the BGR image to RGB
    print('RGB image')
    cv2_imshow(newimg)
    grayimg=cv2.cvtColor(newimg,cv2.COLOR_RGB2GRAY) #converting the RGB image to Grayscale
    print('Gray Image')
    cv2_imshow(grayimg)
    inv_img=255-grayimg #inverting the image
    blur=cv2.GaussianBlur(inv_img,(15,15),0)    #applying the Gaussian blur to blur the image
    print('Blurred Image')
    cv2_imshow(blur)
    inv_blur=255-blur   #inverting the image again
    pencil_sketch=cv2.divide(grayimg,inv_blur,scale=256.0)  #pencil sketch using the divide function
    print('Pencil Sketch')
    cv2_imshow(pencil_sketch)
    #cv2.waitKey(0)

# %% [markdown]
# ### Converting an Image to Pencil Sketch

# %%
sketch('MonaLisa.jpg')
# Out:
# Loaded Image
# <PIL.Image.Image image mode=RGB size=200x298 at 0x7FC268E91A50>
# RGB image
# <PIL.Image.Image image mode=RGB size=200x298 at 0x7FC268E10E50>
# Gray Image
# <PIL.Image.Image image mode=L size=200x298 at 0x7FC268E10F50>
# Blurred Image
# <PIL.Image.Image image mode=L size=200x298 at 0x7FC268E00C90>
# Pencil Sketch
# <PIL.Image.Image image mode=L size=200x298 at 0x7FC268E91D90>
